# %%
import math
import numpy as np
import pylab as pl
x=0.0
xi=0.0
x1=-10
funcionx= []
funciony= []
while(x<=10):
        an=xi
        xi=(3+(xi)**2)/2
        print "valores de xi de la 1 funcion:"
        print x, "\t", an, "\t",xi
       
        x=x+1
     
        
        
print        
while(x1<=10):
    y=(x1)**2-2*x1+3
    print"valores de la funcion:"
    print x1, "\t", y 
    funcionx.append(x1)
    x1=x1+1
    funciony.append(y)
   
    
fun = pl.plot(funcionx,funciony, "r")
pl.title("grafica de 1 funcion")
pl.xlabel("x")
pl.ylabel("y")
pl.xlim(-10, 10)
pl.ylim(0.0, 123)
pl.legend([fun], ("funcion hallada"), "best", numpoints=1)
pl.grid(True)
pl.show()
# Out:
# valores de xi de la 1 funcion:
# 0.0 	0.0 	1.5
# valores de xi de la 1 funcion:
# 1.0 	1.5 	2.625
# valores de xi de la 1 funcion:
# 2.0 	2.625 	4.9453125
# valores de xi de la 1 funcion:
# 3.0 	4.9453125 	13.7280578613
# valores de xi de la 1 funcion:
# 4.0 	13.7280578613 	95.729786322
# valores de xi de la 1 funcion:
# 5.0 	95.729786322 	4583.59599463
# valores de xi de la 1 funcion:
# 6.0 	4583.59599463 	10504677.621
# valores de xi de la 1 funcion:
# 7.0 	10504677.621 	5.51741259603e+13
# valores de xi de la 1 funcion:
# 8.0 	5.51741259603e+13 	1.52209208774e+27
# valores de xi de la 1 funcion:
# 9.0 	1.52209208774e+27 	1.15838216179e+54
# valores de xi de la 1 funcion:
# 10.0 	1.15838216179e+54 	6.70924616372e+107
#
# valores de la funcion:
# -10 	123
# valores de la funcion:
# -9 	102
# valores de la funcion:
# -8 	83
# valores de la funcion:
# -7 	66
# valores de la funcion:
# -6 	51
# valores de la funcion:
# -5 	38
# valores de la funcion:
# -4 	27
# valores de la funcion:
# ...

# %%
import math
import numpy as np
import pylab as pl
x=0.0
x1=-10
ea=0
xi=0.0
funcionx= []
funciony= []
while(x<=10):
        an=xi
        xi= math.exp(-xi)
        print "valores de xi de la 2 funcion:"
        print x, "\t",an, "\t",xi,"\t",ea
        
        x=x+1
        ea=math.fabs((xi-an)/xi)*100
        
        
        
        
while(x1<=10):
    y=math.exp(-x1)-x1
    funcionx.append(x1)
    print"valores de la funcion:"
    print x1, "\t", y
    x1=x1+1
    funciony.append(y)
    

    

fun2 = pl.plot(funcionx,funciony, "r")
pl.title("grafica de funcion 2")
pl.xlabel("x")
pl.ylabel("y")
pl.xlim(-2, 2)
pl.ylim(-2, 2)
pl.legend([fun2], ("funcion hallada"), "best", numpoints=1)
pl.grid(True)
pl.show()
# Out:
# valores de xi de la 2 funcion:
# 0.0 	0.0 	1.0 	0
# valores de xi de la 2 funcion:
# 1.0 	1.0 	0.367879441171 	100.0
# valores de xi de la 2 funcion:
# 2.0 	0.367879441171 	0.692200627555 	171.828182846
# valores de xi de la 2 funcion:
# 3.0 	0.692200627555 	0.500473500564 	46.8536394613
# valores de xi de la 2 funcion:
# 4.0 	0.500473500564 	0.606243535086 	38.3091465933
# valores de xi de la 2 funcion:
# 5.0 	0.606243535086 	0.545395785975 	17.4467896812
# valores de xi de la 2 funcion:
# 6.0 	0.545395785975 	0.579612335503 	11.1566225254
# valores de xi de la 2 funcion:
# 7.0 	0.579612335503 	0.560115461361 	5.90335081441
# valores de xi de la 2 funcion:
# 8.0 	0.560115461361 	0.57114311508 	3.48086697962
# valores de xi de la 2 funcion:
# 9.0 	0.57114311508 	0.564879347391 	1.93080393126
# valores de xi de la 2 funcion:
# 10.0 	0.564879347391 	0.568428725029 	1.10886824205
# valores de la funcion:
# -10 	22036.4657948
# valores de la funcion:
# -9 	8112.08392758
# ...
