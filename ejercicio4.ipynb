# %%
import pylab as plt
import math
x1=[]
x2=[]

x3=[]
x4=[]

def a():
    x=-8
    y=0    
    while (x<=10):   
        print "valor",x,"valor funcion",y
        y= 3 + ( x/2 )
        x=x+0.5
        x1.append(x)
        x2.append(y)        
        
def b():
    xs=-8
    t=0.0
    while (xs<=10): 
        print"valor", xs,"valor funcion",t
        t= (34 - xs )/6
        xs=xs+0.5
        x3.append(xs)
        x4.append(t)
        
print " ecuacion 1"
a()
print
print " ecuacion 2"
print
b()
# Out:
#  ecuacion 1
# valor -8 valor funcion 0
# valor -7.5 valor funcion -1
# valor -7.0 valor funcion -0.75
# valor -6.5 valor funcion -0.5
# valor -6.0 valor funcion -0.25
# valor -5.5 valor funcion 0.0
# valor -5.0 valor funcion 0.25
# valor -4.5 valor funcion 0.5
# valor -4.0 valor funcion 0.75
# valor -3.5 valor funcion 1.0
# valor -3.0 valor funcion 1.25
# valor -2.5 valor funcion 1.5
# valor -2.0 valor funcion 1.75
# valor -1.5 valor funcion 2.0
# valor -1.0 valor funcion 2.25
# valor -0.5 valor funcion 2.5
# valor 0.0 valor funcion 2.75
# valor 0.5 valor funcion 3.0
# valor 1.0 valor funcion 3.25
# valor 1.5 valor funcion 3.5
# valor 2.0 valor funcion 3.75
# valor 2.5 valor funcion 4.0
# valor 3.0 valor funcion 4.25
# valor 3.5 valor funcion 4.5
# valor 4.0 valor funcion 4.75
# valor 4.5 valor funcion 5.0
# valor 5.0 valor funcion 5.25
# valor 5.5 valor funcion 5.5
# valor 6.0 valor funcion 5.75
# valor 6.5 valor funcion 6.0
# valor 7.0 valor funcion 6.25
# ...
