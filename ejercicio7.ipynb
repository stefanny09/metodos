# %%
import pylab as plt
import math
x1=[]
x2=[]
x3=[]
x4=[]

def a():
    x=-5
    y=0    
    while (x<=15):   
        print "valor",x,"valor de funcion:", y
        y= 9.5 + ( 0.5*x )
        x=x+0.5
        x1.append(x)
        x2.append(y)        
        
def b():
    xs=-5
    t=0
    while (xs<=15): 
        print "valor:",xs,"valo de funcion:", t
        t= 9.4 + ( t*0.51 )
        xs=xs+0.5
        x3.append(xs)
        x4.append(t)
        
print "ecuacion 1"
print
a()
print
print " ecuacion 2"
print
b()
# Out:
# ecuacion 1
#
# valor -5 valor de funcion: 0
# valor -4.5 valor de funcion: 7.0
# valor -4.0 valor de funcion: 7.25
# valor -3.5 valor de funcion: 7.5
# valor -3.0 valor de funcion: 7.75
# valor -2.5 valor de funcion: 8.0
# valor -2.0 valor de funcion: 8.25
# valor -1.5 valor de funcion: 8.5
# valor -1.0 valor de funcion: 8.75
# valor -0.5 valor de funcion: 9.0
# valor 0.0 valor de funcion: 9.25
# valor 0.5 valor de funcion: 9.5
# valor 1.0 valor de funcion: 9.75
# valor 1.5 valor de funcion: 10.0
# valor 2.0 valor de funcion: 10.25
# valor 2.5 valor de funcion: 10.5
# valor 3.0 valor de funcion: 10.75
# valor 3.5 valor de funcion: 11.0
# valor 4.0 valor de funcion: 11.25
# valor 4.5 valor de funcion: 11.5
# valor 5.0 valor de funcion: 11.75
# valor 5.5 valor de funcion: 12.0
# valor 6.0 valor de funcion: 12.25
# valor 6.5 valor de funcion: 12.5
# valor 7.0 valor de funcion: 12.75
# valor 7.5 valor de funcion: 13.0
# valor 8.0 valor de funcion: 13.25
# ...
