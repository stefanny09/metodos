# %%
import math
import numpy as np
import pylab as pl
x1=0
x2=0
x3=0
x4=0
x5=0
x6=0
i=3
x5=0
x6=0
funcion = []
funcion1 =[]
funcion2 =[]
y1 = []
y2= []
y3 =[]
y4= []
y5 =[]
y6= []
   
def a(i):
  

    while i<=5:
        x1=(1.0/2.0)*i +1.0

        y1.append(x1)
        x2=(1.0/2.0)*i+1.0/2.0
        print "x=", i
        print "funcion 1:",x1
        funcion.append(i)
        y2.append(x2)
        print "funcion 2:",x2
        i=i+1

def b(i):
    while i<=5:
        x3=(1.0/2.0)*i +1.0
        y3.append(x3)
        x4=((2.0+i)/2.0)
        print "x=", i
        print "funcion 3:",x3
        funcion1.append(i)
        y4.append(x4)
        print "funcion 4:",x4
        i=i+1
        
def c(i):
    i=0
    while i<=5:
        
        x5=(1.0/2.0)*i +1.0
        y5.append(x5)
        x6=1.1 +(2.3/5.0)*i
        print "x=", i
        print "funcion 5:",x5
        funcion2.append(i)
        y6.append(x6)
        print "funcion 6:",x6
        i=i+1
a(i)
print

f1 = pl.plot(funcion,y1, "r")
f2 = pl.plot(funcion, y2, "g")
pl.title("grafica 1")
pl.xlabel("Tiempo")
pl.ylabel("Velocidad")

pl.show()
print "segunda grafica"
print
b(i)
print
f3 = pl.plot(funcion1,y3, "r")
f4 = pl.plot(funcion1, y4, "g")
pl.title("grafica 2")
pl.xlabel("Tiempo")
pl.ylabel("Velocidad")
pl.show()

print "grafica 3"
print
c(i)

f5 = pl.plot(funcion2,y5, "r")
f6 = pl.plot(funcion2, y6, "g")
pl.title("grafica 3")
pl.xlabel("Tiempo")
pl.ylabel("Velocidad")
pl.show()
# Out:
# x= 3
# funcion 1: 2.5
# funcion 2: 2.0
# x= 4
# funcion 1: 3.0
# funcion 2: 2.5
# x= 5
# funcion 1: 3.5
# funcion 2: 3.0
#
# segunda grafica
#
# x= 3
# funcion 3: 2.5
# funcion 4: 2.5
# x= 4
# funcion 3: 3.0
# funcion 4: 3.0
# x= 5
# funcion 3: 3.5
# funcion 4: 3.5
#
# grafica 3
#
# x= 0
# funcion 5: 1.0
# funcion 6: 1.1
# x= 1
# funcion 5: 1.5
# funcion 6: 1.56
# x= 2
# funcion 5: 2.0
# funcion 6: 2.02
# x= 3
# funcion 5: 2.5
# funcion 6: 2.48
# x= 4
# funcion 5: 3.0
# funcion 6: 2.94
# x= 5
# funcion 5: 3.5
# funcion 6: 3.4
